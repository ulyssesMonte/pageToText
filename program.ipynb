# %%
import os
import cv2
from PIL import Image
import pytesseract
# Caminho para o executável do Tesseract (necessário no Windows)
pytesseract.pytesseract.tesseract_cmd = r'D:/docs'

# %%
# Função para pré-processar a imagem usando OpenCV
def preprocessar_imagem(caminho_imagem):
    try:
        # Carrega a imagem
        img = cv2.imread(caminho_imagem)

        # Converte para escala de cinza
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Aplica um filtro de suavização (blur) para reduzir ruídos
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)

        # Binariza a imagem (preto e branco)
        _, binary = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

        return binary
    except Exception as e:
        print(f"Erro ao pré-processar a imagem {caminho_imagem}: {e}")
        return None

# %%
def extrair_texto_da_imagem(imagem_path):
    try:
        # Pré-processa a imagem
        img_preprocessada = preprocessar_imagem(imagem_path)

        if img_preprocessada is None:
            return None

        # Converte a imagem processada para o formato PIL
        img_pil = Image.fromarray(img_preprocessada)

        # Extrai o texto usando pytesseract
        texto = pytesseract.image_to_string(img_pil, lang='por')  # Define o idioma como português
        return texto.strip()  # Remove espaços em branco desnecessários
    except Exception as e:
        print(f"Erro ao processar a imagem {imagem_path}: {e}")
        return None

# %%
# Pasta onde estão as imagens
pasta_imagens = r"D:/docs/docs"

# Pasta de saída
pasta_saida = r"D:/docs/docs/output"
# os.makedirs(pasta_saida, exist_ok=True)  # Garante que o diretório existe

# Arquivo de saída consolidado (corrigido: agora inclui o nome do arquivo)
arquivo_saida_consolidado = os.path.join(pasta_saida, "livro_completo.txt")

# Processa todas as imagens numeradas de 0 a 330
with open(arquivo_saida_consolidado, "w", encoding="utf-8") as arquivo_saida:
    for i in range(333):  # De 0 a 330 (inclusive)
        nome_arquivo = f"{i}.jpg"  # Nome do arquivo da imagem
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)
        
        if os.path.exists(caminho_imagem):
            print(f"Processando: {caminho_imagem}")
            
            # Extrai o texto da imagem
            texto_extraido = extrair_texto_da_imagem(caminho_imagem)
            
            if texto_extraido:
                arquivo_saida.write(f"=== Página {i} ===\n")
                arquivo_saida.write(texto_extraido + "\n")
            else:
                arquivo_saida.write(f"=== Página {i} ===\n")
                arquivo_saida.write("[Texto não detectado]\n")
        else:
            print(f"Imagem não encontrada: {caminho_imagem}")
            arquivo_saida.write(f"=== Página {i} ===\n")
            arquivo_saida.write("[Vazia]\n")
        
        # Adiciona uma linha de separação entre as páginas
        arquivo_saida.write("-" * 50 + "\n\n")

print(f"Processamento concluído! Texto consolidado salvo em: {arquivo_saida_consolidado}")
# Out:
# Processando: D:/docs/docs\0.jpg
# Erro ao processar a imagem D:/docs/docs\0.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\1.jpg
# Erro ao processar a imagem D:/docs/docs\1.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\2.jpg
# Processando: D:/docs/docs\3.jpg
# Erro ao processar a imagem D:/docs/docs\3.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\4.jpg
# Erro ao processar a imagem D:/docs/docs\4.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\5.jpg
# Erro ao processar a imagem D:/docs/docs\5.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\6.jpg
# Erro ao processar a imagem D:/docs/docs\6.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\7.jpg
# Erro ao processar a imagem D:/docs/docs\7.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\8.jpg
# Processando: D:/docs/docs\9.jpg
# Erro ao processar a imagem D:/docs/docs\9.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\10.jpg
# Processando: D:/docs/docs\11.jpg
# Erro ao processar a imagem D:/docs/docs\11.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\12.jpg
# Erro ao processar a imagem D:/docs/docs\12.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\13.jpg
# Erro ao processar a imagem D:/docs/docs\13.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\14.jpg
# Erro ao processar a imagem D:/docs/docs\14.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\15.jpg
# Erro ao processar a imagem D:/docs/docs\15.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\16.jpg
# Erro ao processar a imagem D:/docs/docs\16.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\17.jpg
# Erro ao processar a imagem D:/docs/docs\17.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\18.jpg
# Erro ao processar a imagem D:/docs/docs\18.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\19.jpg
# Erro ao processar a imagem D:/docs/docs\19.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\20.jpg
# Erro ao processar a imagem D:/docs/docs\20.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\21.jpg
# Erro ao processar a imagem D:/docs/docs\21.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\22.jpg
# Erro ao processar a imagem D:/docs/docs\22.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\23.jpg
# Erro ao processar a imagem D:/docs/docs\23.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\24.jpg
# Erro ao processar a imagem D:/docs/docs\24.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\25.jpg
# Erro ao processar a imagem D:/docs/docs\25.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\26.jpg
# Processando: D:/docs/docs\27.jpg
# Erro ao processar a imagem D:/docs/docs\27.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\28.jpg
# Processando: D:/docs/docs\29.jpg
# Erro ao processar a imagem D:/docs/docs\29.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\30.jpg
# Erro ao processar a imagem D:/docs/docs\30.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\31.jpg
# Erro ao processar a imagem D:/docs/docs\31.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\32.jpg
# Erro ao processar a imagem D:/docs/docs\32.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\33.jpg
# Erro ao processar a imagem D:/docs/docs\33.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\34.jpg
# Erro ao processar a imagem D:/docs/docs\34.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\35.jpg
# Erro ao processar a imagem D:/docs/docs\35.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\36.jpg
# Erro ao processar a imagem D:/docs/docs\36.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\37.jpg
# Erro ao processar a imagem D:/docs/docs\37.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\38.jpg
# Erro ao processar a imagem D:/docs/docs\38.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\39.jpg
# Erro ao processar a imagem D:/docs/docs\39.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\40.jpg
# Erro ao processar a imagem D:/docs/docs\40.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\41.jpg
# Imagem não encontrada: D:/docs/docs\42.jpg
# Processando: D:/docs/docs\43.jpg
# Erro ao processar a imagem D:/docs/docs\43.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\44.jpg
# Processando: D:/docs/docs\45.jpg
# Erro ao processar a imagem D:/docs/docs\45.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\46.jpg
# Erro ao processar a imagem D:/docs/docs\46.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\47.jpg
# Erro ao processar a imagem D:/docs/docs\47.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\48.jpg
# Erro ao processar a imagem D:/docs/docs\48.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\49.jpg
# Erro ao processar a imagem D:/docs/docs\49.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\50.jpg
# Erro ao processar a imagem D:/docs/docs\50.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\51.jpg
# Erro ao processar a imagem D:/docs/docs\51.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\52.jpg
# Erro ao processar a imagem D:/docs/docs\52.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\53.jpg
# Erro ao processar a imagem D:/docs/docs\53.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\54.jpg
# Erro ao processar a imagem D:/docs/docs\54.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\55.jpg
# Erro ao processar a imagem D:/docs/docs\55.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\56.jpg
# Erro ao processar a imagem D:/docs/docs\56.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\57.jpg
# Erro ao processar a imagem D:/docs/docs\57.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\58.jpg
# Erro ao processar a imagem D:/docs/docs\58.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\59.jpg
# Erro ao processar a imagem D:/docs/docs\59.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\60.jpg
# Erro ao processar a imagem D:/docs/docs\60.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\61.jpg
# Erro ao processar a imagem D:/docs/docs\61.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\62.jpg
# Erro ao processar a imagem D:/docs/docs\62.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\63.jpg
# Processando: D:/docs/docs\64.jpg
# Erro ao processar a imagem D:/docs/docs\64.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\65.jpg
# Erro ao processar a imagem D:/docs/docs\65.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\66.jpg
# Erro ao processar a imagem D:/docs/docs\66.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\67.jpg
# Erro ao processar a imagem D:/docs/docs\67.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\68.jpg
# Erro ao processar a imagem D:/docs/docs\68.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\69.jpg
# Erro ao processar a imagem D:/docs/docs\69.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\70.jpg
# Erro ao processar a imagem D:/docs/docs\70.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\71.jpg
# Erro ao processar a imagem D:/docs/docs\71.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\72.jpg
# Erro ao processar a imagem D:/docs/docs\72.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\73.jpg
# Erro ao processar a imagem D:/docs/docs\73.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\74.jpg
# Erro ao processar a imagem D:/docs/docs\74.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\75.jpg
# Erro ao processar a imagem D:/docs/docs\75.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\76.jpg
# Processando: D:/docs/docs\77.jpg
# Erro ao processar a imagem D:/docs/docs\77.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\78.jpg
# Processando: D:/docs/docs\79.jpg
# Erro ao processar a imagem D:/docs/docs\79.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\80.jpg
# Erro ao processar a imagem D:/docs/docs\80.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\81.jpg
# Erro ao processar a imagem D:/docs/docs\81.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\82.jpg
# Erro ao processar a imagem D:/docs/docs\82.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\83.jpg
# Erro ao processar a imagem D:/docs/docs\83.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\84.jpg
# Erro ao processar a imagem D:/docs/docs\84.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\85.jpg
# Erro ao processar a imagem D:/docs/docs\85.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\86.jpg
# Erro ao processar a imagem D:/docs/docs\86.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\87.jpg
# Erro ao processar a imagem D:/docs/docs\87.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\88.jpg
# Erro ao processar a imagem D:/docs/docs\88.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\89.jpg
# Erro ao processar a imagem D:/docs/docs\89.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\90.jpg
# Erro ao processar a imagem D:/docs/docs\90.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\91.jpg
# Erro ao processar a imagem D:/docs/docs\91.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\92.jpg
# Erro ao processar a imagem D:/docs/docs\92.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\93.jpg
# Erro ao processar a imagem D:/docs/docs\93.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\94.jpg
# Processando: D:/docs/docs\95.jpg
# Erro ao processar a imagem D:/docs/docs\95.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\96.jpg
# Processando: D:/docs/docs\97.jpg
# Erro ao processar a imagem D:/docs/docs\97.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\98.jpg
# Erro ao processar a imagem D:/docs/docs\98.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\99.jpg
# Erro ao processar a imagem D:/docs/docs\99.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\100.jpg
# Erro ao processar a imagem D:/docs/docs\100.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\101.jpg
# Erro ao processar a imagem D:/docs/docs\101.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\102.jpg
# Erro ao processar a imagem D:/docs/docs\102.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\103.jpg
# Erro ao processar a imagem D:/docs/docs\103.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\104.jpg
# Processando: D:/docs/docs\105.jpg
# Erro ao processar a imagem D:/docs/docs\105.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\106.jpg
# Processando: D:/docs/docs\107.jpg
# Erro ao processar a imagem D:/docs/docs\107.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\108.jpg
# Erro ao processar a imagem D:/docs/docs\108.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\109.jpg
# Erro ao processar a imagem D:/docs/docs\109.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\110.jpg
# Erro ao processar a imagem D:/docs/docs\110.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\111.jpg
# Erro ao processar a imagem D:/docs/docs\111.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\112.jpg
# Erro ao processar a imagem D:/docs/docs\112.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\113.jpg
# Erro ao processar a imagem D:/docs/docs\113.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\114.jpg
# Erro ao processar a imagem D:/docs/docs\114.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\115.jpg
# Erro ao processar a imagem D:/docs/docs\115.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\116.jpg
# Erro ao processar a imagem D:/docs/docs\116.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\117.jpg
# Erro ao processar a imagem D:/docs/docs\117.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\118.jpg
# Erro ao processar a imagem D:/docs/docs\118.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\119.jpg
# Erro ao processar a imagem D:/docs/docs\119.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\120.jpg
# Processando: D:/docs/docs\121.jpg
# Erro ao processar a imagem D:/docs/docs\121.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\122.jpg
# Processando: D:/docs/docs\123.jpg
# Erro ao processar a imagem D:/docs/docs\123.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\124.jpg
# Erro ao processar a imagem D:/docs/docs\124.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\125.jpg
# Erro ao processar a imagem D:/docs/docs\125.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\126.jpg
# Erro ao processar a imagem D:/docs/docs\126.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\127.jpg
# Erro ao processar a imagem D:/docs/docs\127.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\128.jpg
# Erro ao processar a imagem D:/docs/docs\128.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\129.jpg
# Erro ao processar a imagem D:/docs/docs\129.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\130.jpg
# Erro ao processar a imagem D:/docs/docs\130.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\131.jpg
# Erro ao processar a imagem D:/docs/docs\131.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\132.jpg
# Erro ao processar a imagem D:/docs/docs\132.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\133.jpg
# Erro ao processar a imagem D:/docs/docs\133.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\134.jpg
# Erro ao processar a imagem D:/docs/docs\134.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\135.jpg
# Erro ao processar a imagem D:/docs/docs\135.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\136.jpg
# Erro ao processar a imagem D:/docs/docs\136.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\137.jpg
# Erro ao processar a imagem D:/docs/docs\137.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\138.jpg
# Processando: D:/docs/docs\139.jpg
# Erro ao processar a imagem D:/docs/docs\139.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\140.jpg
# Processando: D:/docs/docs\141.jpg
# Erro ao processar a imagem D:/docs/docs\141.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\142.jpg
# Erro ao processar a imagem D:/docs/docs\142.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\143.jpg
# Erro ao processar a imagem D:/docs/docs\143.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\144.jpg
# Erro ao processar a imagem D:/docs/docs\144.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\145.jpg
# Erro ao processar a imagem D:/docs/docs\145.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\146.jpg
# Erro ao processar a imagem D:/docs/docs\146.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\147.jpg
# Erro ao processar a imagem D:/docs/docs\147.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\148.jpg
# Erro ao processar a imagem D:/docs/docs\148.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\149.jpg
# Erro ao processar a imagem D:/docs/docs\149.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\150.jpg
# Erro ao processar a imagem D:/docs/docs\150.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\151.jpg
# Erro ao processar a imagem D:/docs/docs\151.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\152.jpg
# Processando: D:/docs/docs\153.jpg
# Erro ao processar a imagem D:/docs/docs\153.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\154.jpg
# Erro ao processar a imagem D:/docs/docs\154.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\155.jpg
# Erro ao processar a imagem D:/docs/docs\155.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\156.jpg
# Erro ao processar a imagem D:/docs/docs\156.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\157.jpg
# Erro ao processar a imagem D:/docs/docs\157.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\158.jpg
# Erro ao processar a imagem D:/docs/docs\158.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\159.jpg
# Erro ao processar a imagem D:/docs/docs\159.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\160.jpg
# Erro ao processar a imagem D:/docs/docs\160.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\161.jpg
# Erro ao processar a imagem D:/docs/docs\161.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\162.jpg
# Erro ao processar a imagem D:/docs/docs\162.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\163.jpg
# Erro ao processar a imagem D:/docs/docs\163.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\164.jpg
# Erro ao processar a imagem D:/docs/docs\164.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\165.jpg
# Erro ao processar a imagem D:/docs/docs\165.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\166.jpg
# Erro ao processar a imagem D:/docs/docs\166.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\167.jpg
# Erro ao processar a imagem D:/docs/docs\167.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\168.jpg
# Processando: D:/docs/docs\169.jpg
# Erro ao processar a imagem D:/docs/docs\169.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\170.jpg
# Processando: D:/docs/docs\171.jpg
# Erro ao processar a imagem D:/docs/docs\171.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\172.jpg
# Erro ao processar a imagem D:/docs/docs\172.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\173.jpg
# Erro ao processar a imagem D:/docs/docs\173.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\174.jpg
# Erro ao processar a imagem D:/docs/docs\174.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\175.jpg
# Erro ao processar a imagem D:/docs/docs\175.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\176.jpg
# Processando: D:/docs/docs\177.jpg
# Erro ao processar a imagem D:/docs/docs\177.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\178.jpg
# Erro ao processar a imagem D:/docs/docs\178.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\179.jpg
# Erro ao processar a imagem D:/docs/docs\179.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\180.jpg
# Erro ao processar a imagem D:/docs/docs\180.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\181.jpg
# Erro ao processar a imagem D:/docs/docs\181.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\182.jpg
# Erro ao processar a imagem D:/docs/docs\182.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\183.jpg
# Erro ao processar a imagem D:/docs/docs\183.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\184.jpg
# Erro ao processar a imagem D:/docs/docs\184.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\185.jpg
# Erro ao processar a imagem D:/docs/docs\185.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\186.jpg
# Erro ao processar a imagem D:/docs/docs\186.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\187.jpg
# Erro ao processar a imagem D:/docs/docs\187.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\188.jpg
# Erro ao processar a imagem D:/docs/docs\188.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\189.jpg
# Erro ao processar a imagem D:/docs/docs\189.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\190.jpg
# Processando: D:/docs/docs\191.jpg
# Erro ao processar a imagem D:/docs/docs\191.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\192.jpg
# Erro ao processar a imagem D:/docs/docs\192.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\193.jpg
# Erro ao processar a imagem D:/docs/docs\193.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\194.jpg
# Erro ao processar a imagem D:/docs/docs\194.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\195.jpg
# Erro ao processar a imagem D:/docs/docs\195.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\196.jpg
# Erro ao processar a imagem D:/docs/docs\196.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\197.jpg
# Erro ao processar a imagem D:/docs/docs\197.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\198.jpg
# Erro ao processar a imagem D:/docs/docs\198.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\199.jpg
# Erro ao processar a imagem D:/docs/docs\199.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\200.jpg
# Erro ao processar a imagem D:/docs/docs\200.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\201.jpg
# Erro ao processar a imagem D:/docs/docs\201.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\202.jpg
# Erro ao processar a imagem D:/docs/docs\202.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\203.jpg
# Erro ao processar a imagem D:/docs/docs\203.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\204.jpg
# Erro ao processar a imagem D:/docs/docs\204.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\205.jpg
# Erro ao processar a imagem D:/docs/docs\205.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\206.jpg
# Erro ao processar a imagem D:/docs/docs\206.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\207.jpg
# Erro ao processar a imagem D:/docs/docs\207.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\208.jpg
# Erro ao processar a imagem D:/docs/docs\208.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\209.jpg
# Erro ao processar a imagem D:/docs/docs\209.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\210.jpg
# Erro ao processar a imagem D:/docs/docs\210.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\211.jpg
# Erro ao processar a imagem D:/docs/docs\211.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\212.jpg
# Erro ao processar a imagem D:/docs/docs\212.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\213.jpg
# Erro ao processar a imagem D:/docs/docs\213.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\214.jpg
# Erro ao processar a imagem D:/docs/docs\214.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\215.jpg
# Erro ao processar a imagem D:/docs/docs\215.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\216.jpg
# Processando: D:/docs/docs\217.jpg
# Erro ao processar a imagem D:/docs/docs\217.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\218.jpg
# Erro ao processar a imagem D:/docs/docs\218.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\219.jpg
# Erro ao processar a imagem D:/docs/docs\219.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\220.jpg
# Erro ao processar a imagem D:/docs/docs\220.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\221.jpg
# Erro ao processar a imagem D:/docs/docs\221.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\222.jpg
# Erro ao processar a imagem D:/docs/docs\222.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\223.jpg
# Erro ao processar a imagem D:/docs/docs\223.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\224.jpg
# Erro ao processar a imagem D:/docs/docs\224.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\225.jpg
# Erro ao processar a imagem D:/docs/docs\225.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\226.jpg
# Erro ao processar a imagem D:/docs/docs\226.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\227.jpg
# Erro ao processar a imagem D:/docs/docs\227.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\228.jpg
# Erro ao processar a imagem D:/docs/docs\228.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\229.jpg
# Erro ao processar a imagem D:/docs/docs\229.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\230.jpg
# Erro ao processar a imagem D:/docs/docs\230.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\231.jpg
# Erro ao processar a imagem D:/docs/docs\231.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\232.jpg
# Erro ao processar a imagem D:/docs/docs\232.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\233.jpg
# Erro ao processar a imagem D:/docs/docs\233.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\234.jpg
# Erro ao processar a imagem D:/docs/docs\234.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\235.jpg
# Erro ao processar a imagem D:/docs/docs\235.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\236.jpg
# Erro ao processar a imagem D:/docs/docs\236.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\237.jpg
# Erro ao processar a imagem D:/docs/docs\237.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\238.jpg
# Processando: D:/docs/docs\239.jpg
# Erro ao processar a imagem D:/docs/docs\239.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\240.jpg
# Erro ao processar a imagem D:/docs/docs\240.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\241.jpg
# Erro ao processar a imagem D:/docs/docs\241.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\242.jpg
# Erro ao processar a imagem D:/docs/docs\242.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\243.jpg
# Erro ao processar a imagem D:/docs/docs\243.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\244.jpg
# Erro ao processar a imagem D:/docs/docs\244.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\245.jpg
# Erro ao processar a imagem D:/docs/docs\245.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\246.jpg
# Erro ao processar a imagem D:/docs/docs\246.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\247.jpg
# Erro ao processar a imagem D:/docs/docs\247.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\248.jpg
# Erro ao processar a imagem D:/docs/docs\248.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\249.jpg
# Erro ao processar a imagem D:/docs/docs\249.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\250.jpg
# Processando: D:/docs/docs\251.jpg
# Erro ao processar a imagem D:/docs/docs\251.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\252.jpg
# Processando: D:/docs/docs\253.jpg
# Erro ao processar a imagem D:/docs/docs\253.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\254.jpg
# Erro ao processar a imagem D:/docs/docs\254.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\255.jpg
# Erro ao processar a imagem D:/docs/docs\255.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\256.jpg
# Erro ao processar a imagem D:/docs/docs\256.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\257.jpg
# Erro ao processar a imagem D:/docs/docs\257.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\258.jpg
# Erro ao processar a imagem D:/docs/docs\258.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\259.jpg
# Erro ao processar a imagem D:/docs/docs\259.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\260.jpg
# Erro ao processar a imagem D:/docs/docs\260.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\261.jpg
# Erro ao processar a imagem D:/docs/docs\261.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\262.jpg
# Erro ao processar a imagem D:/docs/docs\262.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\263.jpg
# Erro ao processar a imagem D:/docs/docs\263.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\264.jpg
# Processando: D:/docs/docs\265.jpg
# Erro ao processar a imagem D:/docs/docs\265.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\266.jpg
# Processando: D:/docs/docs\267.jpg
# Erro ao processar a imagem D:/docs/docs\267.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\268.jpg
# Erro ao processar a imagem D:/docs/docs\268.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\269.jpg
# Erro ao processar a imagem D:/docs/docs\269.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\270.jpg
# Erro ao processar a imagem D:/docs/docs\270.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\271.jpg
# Erro ao processar a imagem D:/docs/docs\271.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\272.jpg
# Erro ao processar a imagem D:/docs/docs\272.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\273.jpg
# Erro ao processar a imagem D:/docs/docs\273.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\274.jpg
# Erro ao processar a imagem D:/docs/docs\274.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\275.jpg
# Erro ao processar a imagem D:/docs/docs\275.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\276.jpg
# Processando: D:/docs/docs\277.jpg
# Erro ao processar a imagem D:/docs/docs\277.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\278.jpg
# Processando: D:/docs/docs\279.jpg
# Erro ao processar a imagem D:/docs/docs\279.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\280.jpg
# Erro ao processar a imagem D:/docs/docs\280.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\281.jpg
# Erro ao processar a imagem D:/docs/docs\281.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\282.jpg
# Erro ao processar a imagem D:/docs/docs\282.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\283.jpg
# Erro ao processar a imagem D:/docs/docs\283.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\284.jpg
# Erro ao processar a imagem D:/docs/docs\284.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\285.jpg
# Erro ao processar a imagem D:/docs/docs\285.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\286.jpg
# Erro ao processar a imagem D:/docs/docs\286.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\287.jpg
# Erro ao processar a imagem D:/docs/docs\287.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\288.jpg
# Erro ao processar a imagem D:/docs/docs\288.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\289.jpg
# Erro ao processar a imagem D:/docs/docs\289.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\290.jpg
# Erro ao processar a imagem D:/docs/docs\290.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\291.jpg
# Erro ao processar a imagem D:/docs/docs\291.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\292.jpg
# Erro ao processar a imagem D:/docs/docs\292.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\293.jpg
# Erro ao processar a imagem D:/docs/docs\293.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\294.jpg
# Processando: D:/docs/docs\295.jpg
# Erro ao processar a imagem D:/docs/docs\295.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\296.jpg
# Processando: D:/docs/docs\297.jpg
# Erro ao processar a imagem D:/docs/docs\297.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\298.jpg
# Erro ao processar a imagem D:/docs/docs\298.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\299.jpg
# Erro ao processar a imagem D:/docs/docs\299.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\300.jpg
# Erro ao processar a imagem D:/docs/docs\300.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\301.jpg
# Erro ao processar a imagem D:/docs/docs\301.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\302.jpg
# Erro ao processar a imagem D:/docs/docs\302.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\303.jpg
# Erro ao processar a imagem D:/docs/docs\303.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\304.jpg
# Erro ao processar a imagem D:/docs/docs\304.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\305.jpg
# Erro ao processar a imagem D:/docs/docs\305.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\306.jpg
# Erro ao processar a imagem D:/docs/docs\306.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\307.jpg
# Erro ao processar a imagem D:/docs/docs\307.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\308.jpg
# Erro ao processar a imagem D:/docs/docs\308.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\309.jpg
# Erro ao processar a imagem D:/docs/docs\309.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\310.jpg
# Erro ao processar a imagem D:/docs/docs\310.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\311.jpg
# Erro ao processar a imagem D:/docs/docs\311.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\312.jpg
# Processando: D:/docs/docs\313.jpg
# Erro ao processar a imagem D:/docs/docs\313.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\314.jpg
# Erro ao processar a imagem D:/docs/docs\314.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\315.jpg
# Erro ao processar a imagem D:/docs/docs\315.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\316.jpg
# Erro ao processar a imagem D:/docs/docs\316.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\317.jpg
# Erro ao processar a imagem D:/docs/docs\317.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\318.jpg
# Erro ao processar a imagem D:/docs/docs\318.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\319.jpg
# Erro ao processar a imagem D:/docs/docs\319.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\320.jpg
# Erro ao processar a imagem D:/docs/docs\320.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\321.jpg
# Erro ao processar a imagem D:/docs/docs\321.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\322.jpg
# Erro ao processar a imagem D:/docs/docs\322.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\323.jpg
# Erro ao processar a imagem D:/docs/docs\323.jpg: [WinError 5] Acesso negado
# Imagem não encontrada: D:/docs/docs\324.jpg
# Processando: D:/docs/docs\325.jpg
# Erro ao processar a imagem D:/docs/docs\325.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\326.jpg
# Erro ao processar a imagem D:/docs/docs\326.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\327.jpg
# Erro ao processar a imagem D:/docs/docs\327.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\328.jpg
# Erro ao processar a imagem D:/docs/docs\328.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\329.jpg
# Erro ao processar a imagem D:/docs/docs\329.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\330.jpg
# Erro ao processar a imagem D:/docs/docs\330.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\331.jpg
# Erro ao processar a imagem D:/docs/docs\331.jpg: [WinError 5] Acesso negado
# Processando: D:/docs/docs\332.jpg
# Erro ao processar a imagem D:/docs/docs\332.jpg: [WinError 5] Acesso negado
# Processamento concluído! Texto consolidado salvo em: D:/docs/docs/output\livro_completo.txt
